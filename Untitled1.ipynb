# %%
import os
print(os.path.exists('data/KDDTrain+.txt'))
# Out:
# False

# %%
import os
print(os.path.exists('data/KDDTrain+.txt'))
# Out:
# False

# %%
import os
print(os.path.exists('data/KDDTrain+.txt'))
# Out:
# False

# %%
import os
print(os.path.exists('data/KDDTrain+.txt'))
# Out:
# False
